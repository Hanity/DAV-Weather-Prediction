# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
# %cd gdrive
# Out:
# /content/gdrive

# %%
ls
# Out:
# MyDrive/  Shareddrives/

# %%
# %cd MyDrive/
# Out:
# /content/gdrive/MyDrive

# %%
ls
# Out:
#  archive/
# 'archive (1)'/
#  chicago-smart-green-infrastructure-monitoring-data.zip
# 'Colab Notebooks'/
# 'DATA ANALYSIS DD..with correction.docx'
#  dc-motor-130.snapshot.3/
#  final.xlsx
#  heatmap_Sensors.png
# 'Hununuw..flash ubuntu'/
#  ICTE.gdoc
# 'Intelligent systems and robotic.docx'
#  ISR.docx
#  ISR.gdoc
# 'ISR New.docx'
#  ISR.odt
#  kaggle.json
# 'Node-red VS MD(2).xlsx'
#  Shareddrives/
#  smart-green-infrastructure-monitoring-sensors-historical.csv
#  smartH.csv
#  smartN.csv
#  socrata_metadata.json
#  SUI.csv
# 'Untitled folder'/

# %% [markdown]
# Descriptive Statistics

# %%
import pandas as pd

smart = pd.read_csv('smart-green-infrastructure-monitoring-sensors-historical.csv')

# %%
smart.shape
# Out:
# (13299699, 16)

# %%
smart.head(100)
# Out:
#                                     Measurement Title  ...                                           Location
# 0   UI Labs Bioswale NWS Probability of Precipitation  ...  {'coordinates': [-87.653996, 41.90715], 'type'...
# 1   UI Labs Bioswale NWS Probability of Precipitation  ...  {'coordinates': [-87.653996, 41.90715], 'type'...
# 2   UI Labs Bioswale NWS Quantitative Precipitatio...  ...  {'coordinates': [-87.653996, 41.90715], 'type'...
# 3   UI Labs Bioswale NWS Quantitative Precipitatio...  ...  {'coordinates': [-87.653996, 41.90715], 'type'...
# 4   UI Labs Bioswale NWS Probability of Precipitation  ...  {'coordinates': [-87.653996, 41.90715], 'type'...
# ..                                                ...  ...                                                ...
# 95      UI Labs Bioswale - Thunder 1: TM1 Temp Sensor  ...  {'coordinates': [-87.653996, 41.90715], 'type'...
# ...

# %%
smart.describe()
# Out:
#        Measurement Value  Data Stream ID  ...      Latitude     Longitude
# count       1.329970e+07    1.329970e+07  ...  1.329970e+07  1.329970e+07
# mean        7.420917e+03    3.777937e+04  ...  4.189926e+01 -8.764536e+01
# std         2.413585e+04    2.660733e+03  ...  8.721549e-02  2.138659e-02
# min        -5.500000e+02    3.326400e+04  ...  4.175311e+01 -8.765972e+01
# 25%         6.700000e+00    3.617600e+04  ...  4.190715e+01 -8.765972e+01
# 50%         1.800000e+02    3.918200e+04  ...  4.190715e+01 -8.765400e+01
# 75%         9.590000e+02    3.920700e+04  ...  4.197309e+01 -8.765400e+01
# max         1.022100e+05    4.011700e+04  ...  4.197309e+01 -8.760773e+01
#
# [8 rows x 6 columns]

# %%
# Only choose descriptive statistics for Meauremet Title and Measurement 

smart[["Measurement Value"]].describe()
smart[[ "Measurement Title"]].describe()
# Out:
#                                     Measurement Title
# count                                        13299699
# unique                                             39
# top     UI Labs Bioswale - Thunder 1: TM1 Temp Sensor
# freq                                           553684

# %%
smart[["Measurement Value"]].describe()
# Out:
#        Measurement Value
# count       1.329970e+07
# mean        7.420917e+03
# std         2.413585e+04
# min        -5.500000e+02
# 25%         6.700000e+00
# 50%         1.800000e+02
# 75%         9.590000e+02
# max         1.022100e+05

# %%
print("How many  sensors are there for each location?")
print(smart["Measurement Title"].value_counts())

print("\n")
# Out:
# How many  sensors are there for each location?
# UI Labs Bioswale - Thunder 1: TM1 Temp Sensor                          553684
# UI Labs Bioswale - Thunder 1: SM1 Soil Moisture Sensor                 553679
# Langley - Thunder 1: TM1 Temp Sensor                                   528686
# Langley - Thunder 1: SM1 Soil Moisture Sensor                          528675
# Langley - Cumulus: Bioswale Calibrated VWC                             528319
# Argyle - Thunder 1: TM1 Temp Sensor                                    520632
# Argyle - Thunder 1: SM1 Soil Moisture Sensor                           520631
# Argyle - Thunder 1: MK-III Weather Station Temp                        496392
# Argyle - Thunder 1: MK-III Weather Station RH                          496387
# Argyle - Thunder 1: MK-III Weather Station Pressure                    496386
# Argyle - Thunder 1: MK-III Weather Station Wind Speed                  496382
# ...

# %%
# The data is from three sensor location in chcago namely UI labs ,Langely and Argyle
#Extract data from only two location to be used for comparison later on.I.e UI labs and Argyle

import re
smart_new =pd.read_csv('smartH.csv')
#smart_new.to_csv('smartH.csv')

# %%
smart_new.describe()
# Out:
#          Unnamed: 0  Measurement Value  ...      Latitude     Longitude
# count  8.074922e+06       8.074922e+06  ...  8.074922e+06  8.074922e+06
# mean   5.234188e+06       8.710983e+03  ...  4.194723e+01 -8.765748e+01
# std    2.999314e+06       2.590837e+04  ...  3.219197e-02  2.797072e-03
# min    0.000000e+00      -5.500000e+02  ...  4.190715e+01 -8.765972e+01
# 25%    2.409867e+06       9.000000e+00  ...  4.190715e+01 -8.765972e+01
# 50%    5.530248e+06       2.120000e+02  ...  4.197309e+01 -8.765972e+01
# 75%    7.823519e+06       2.502000e+03  ...  4.197309e+01 -8.765400e+01
# max    1.013784e+07       1.022100e+05  ...  4.197309e+01 -8.765400e+01
#
# [8 rows x 7 columns]

# %%
print("Median Measurement Value")
print(smart[[ "Measurement Value"]].median())

print("\n")
print("mean value of measurement value")
print(smart[[ "Measurement Value"]].mean())

print("\n")
print("Aggregated descriptive functions")
print(smart.agg({'Measurement Value': ['min', 'mean', 'max', 'median', 'skew'],
             'Measurement Value': ['min', 'max', 'median', 'mean', 'skew']
             }
             )
)
# Out:
# Median Measurement Value
# Measurement Value    180.0
# dtype: float64
#
#
# mean value of measurement value
# Measurement Value    7420.917371
# dtype: float64
#
#
# Aggregated descriptive functions
#         Measurement Value
# min           -550.000000
# max         102210.000000
# median         180.000000
# mean          7420.917371
# skew             3.517956

# %%
print("Median Measurement Value")
print(smart_new[[ "Measurement Value"]].median())

print("\n")
print("mean value of measurement value")
print(smart_new[[ "Measurement Value"]].mean())

print("\n")
print("Aggregated descriptive functions")
print(smart_new.agg({'Measurement Value': ['min', 'mean', 'max', 'median', 'skew'],
             'Measurement Value': ['min', 'max', 'median', 'mean', 'skew']
             }
             )
)
# Out:
# Median Measurement Value
# Measurement Value    212.0
# dtype: float64
#
#
# mean value of measurement value
# Measurement Value    8710.982717
# dtype: float64
#
#
# Aggregated descriptive functions
#         Measurement Value
# min           -550.000000
# max         102210.000000
# median         212.000000
# mean          8710.982717
# skew             3.191218

# %%
groupby_Measurement_Title = smart_new.groupby('Measurement Title')
groupby_Measurement_Title.describe()
# Out:
#                                                    Unnamed: 0  ...  Longitude
#                                                         count  ...        max
# Measurement Title                                              ...
# Argyle - Cumulus: Bioswale Calibrated VWC            192799.0  ... -87.659725
# Argyle - Cumulus: Weather Station Air Temp           349279.0  ... -87.659725
# Argyle - Cumulus: Weather Station Pressure           349279.0  ... -87.659725
# Argyle - Cumulus: Weather Station Rainfall           349277.0  ... -87.659725
# Argyle - Cumulus: Weather Station Wind Speed         349278.0  ... -87.659725
# Argyle - Thunder 1: MK-III Weather Station Pres...   408740.0  ... -87.659725
# Argyle - Thunder 1: MK-III Weather Station RH        408741.0  ... -87.659725
# Argyle - Thunder 1: MK-III Weather Station Rain...   408734.0  ... -87.659725
# Argyle - Thunder 1: MK-III Weather Station Temp      408747.0  ... -87.659725
# ...

# %%
# The data set contains all the sensor value and time  in one column hence to get the value of the temp sensor

new_df = smart_new.loc[(smart_new['Measurement Title'] == 'UI Labs Bioswale - Thunder 1: TM1 Temp Sensor')]
new_RH =smart_new.loc[(smart_new['Measurement Title'] == 'UI Labs Bioswale - Thunder 1: MK-III Weather Station Pressure')]
new_p = smart_new.loc[(smart_new['Measurement Title'] == 'UI Labs Bioswale - Thunder 1: MK-III Weather Station RH')]
new_ArP =smart_new.loc[(smart_new['Measurement Title'] == 'Argyle - Thunder 1: MK-III Weather Station Pressur')]
new_ArT =smart_new.loc[(smart_new['Measurement Title'] == 'Argyle - Thunder 1: MK-III Weather Station Temp')]
new_ArR =smart_new.loc[(smart_new['Measurement Title'] == 'Argyle - Thunder 1: MK-III Weather Station RH')]
values_df = new_df.iloc[:, 4:6]
print(values_df.columns)
# Out:
# Index(['Measurement Medium', 'Measurement Time'], dtype='object')

# %%
new_df.describe()
# Out:
#          Unnamed: 0  Measurement Value  ...      Latitude     Longitude
# count  4.630960e+05      463096.000000  ...  4.630960e+05  4.630960e+05
# mean   4.714275e+06         440.794634  ...  4.190715e+01 -8.765400e+01
# std    3.078779e+06          62.208352  ...  2.523069e-10  1.028668e-09
# min    5.300000e+01         199.000000  ...  4.190715e+01 -8.765400e+01
# 25%    1.888996e+06         401.000000  ...  4.190715e+01 -8.765400e+01
# 50%    4.843254e+06         440.000000  ...  4.190715e+01 -8.765400e+01
# 75%    7.424900e+06         488.000000  ...  4.190715e+01 -8.765400e+01
# max    1.013782e+07         599.000000  ...  4.190715e+01 -8.765400e+01
#
# [8 rows x 7 columns]

# %%
new_RH.describe()
# Out:
#          Unnamed: 0  Measurement Value  ...      Latitude     Longitude
# count  2.486930e+05      248693.000000  ...  2.486930e+05  2.486930e+05
# mean   7.189327e+06        9960.657578  ...  4.190715e+01 -8.765400e+01
# std    1.707074e+06          57.959462  ...  1.820627e-10  3.669392e-10
# min    3.380561e+06        9766.000000  ...  4.190715e+01 -8.765400e+01
# 25%    5.664587e+06        9922.000000  ...  4.190715e+01 -8.765400e+01
# 50%    7.180285e+06        9965.000000  ...  4.190715e+01 -8.765400e+01
# 75%    8.689699e+06        9994.000000  ...  4.190715e+01 -8.765400e+01
# max    1.013782e+07       10148.000000  ...  4.190715e+01 -8.765400e+01
#
# [8 rows x 7 columns]

# %%
new_p.describe()
# Out:
#          Unnamed: 0  Measurement Value  ...      Latitude     Longitude
# count  2.488020e+05      248802.000000  ...  2.488020e+05  2.488020e+05
# mean   7.188129e+06          66.921918  ...  4.190715e+01 -8.765400e+01
# std    1.707819e+06          16.868012  ...  1.821338e-10  3.675645e-10
# min    3.380560e+06          20.000000  ...  4.190715e+01 -8.765400e+01
# 25%    5.662766e+06          55.000000  ...  4.190715e+01 -8.765400e+01
# 50%    7.178998e+06          67.000000  ...  4.190715e+01 -8.765400e+01
# 75%    8.689154e+06          79.000000  ...  4.190715e+01 -8.765400e+01
# max    1.013782e+07         100.000000  ...  4.190715e+01 -8.765400e+01
#
# [8 rows x 7 columns]

# %%
new_ArP.describe()
# Out:
#        Unnamed: 0  Measurement Value  ...  Latitude  Longitude
# count         0.0                0.0  ...       0.0        0.0
# mean          NaN                NaN  ...       NaN        NaN
# std           NaN                NaN  ...       NaN        NaN
# min           NaN                NaN  ...       NaN        NaN
# 25%           NaN                NaN  ...       NaN        NaN
# 50%           NaN                NaN  ...       NaN        NaN
# 75%           NaN                NaN  ...       NaN        NaN
# max           NaN                NaN  ...       NaN        NaN
#
# [8 rows x 7 columns]

# %%
new_ArR.describe()
# Out:
#          Unnamed: 0  Measurement Value  ...      Latitude     Longitude
# count  4.087410e+05      408741.000000  ...  4.087410e+05  4.087410e+05
# mean   4.709629e+06          28.734905  ...  4.197309e+01 -8.765972e+01
# std    3.117544e+06          34.518802  ...  1.679654e-10  3.370393e-10
# min    2.528400e+04          -1.000000  ...  4.197309e+01 -8.765972e+01
# 25%    1.854189e+06          -1.000000  ...  4.197309e+01 -8.765972e+01
# 50%    4.261112e+06          -1.000000  ...  4.197309e+01 -8.765972e+01
# 75%    7.538328e+06          62.000000  ...  4.197309e+01 -8.765972e+01
# max    1.013783e+07         100.000000  ...  4.197309e+01 -8.765972e+01
#
# [8 rows x 7 columns]

# %%
new_ArT.describe()
# Out:
#          Unnamed: 0  Measurement Value  ...      Latitude     Longitude
# count  4.087470e+05      408747.000000  ...  4.087470e+05  4.087470e+05
# mean   4.709632e+06        -197.521968  ...  4.197309e+01 -8.765972e+01
# std    3.117512e+06         384.814315  ...  1.679654e-10  3.369966e-10
# min    2.528300e+04        -550.000000  ...  4.197309e+01 -8.765972e+01
# 25%    1.854212e+06        -550.000000  ...  4.197309e+01 -8.765972e+01
# 50%    4.261195e+06        -550.000000  ...  4.197309e+01 -8.765972e+01
# 75%    7.538236e+06         215.000000  ...  4.197309e+01 -8.765972e+01
# max    1.013783e+07         442.000000  ...  4.197309e+01 -8.765972e+01
#
# [8 rows x 7 columns]

# %%
# The data set contains all the sensor value and time  in one column hence to get the value of the temp sensor from Argyle location

new_AR = smart_new.loc[(smart_new['Measurement Title'] == 'Argyle - Thunder 1: MK-III Weather Station Temp')]
values_AR = new_AR.iloc[:, 4:6]
print(values_AR.columns)
# Out:
# Index(['Measurement Medium', 'Measurement Time'], dtype='object')

# %%
new_df.describe()
# Out:
#          Unnamed: 0  Measurement Value  ...      Latitude     Longitude
# count  4.630960e+05      463096.000000  ...  4.630960e+05  4.630960e+05
# mean   4.714275e+06         440.794634  ...  4.190715e+01 -8.765400e+01
# std    3.078779e+06          62.208352  ...  2.523069e-10  1.028668e-09
# min    5.300000e+01         199.000000  ...  4.190715e+01 -8.765400e+01
# 25%    1.888996e+06         401.000000  ...  4.190715e+01 -8.765400e+01
# 50%    4.843254e+06         440.000000  ...  4.190715e+01 -8.765400e+01
# 75%    7.424900e+06         488.000000  ...  4.190715e+01 -8.765400e+01
# max    1.013782e+07         599.000000  ...  4.190715e+01 -8.765400e+01
#
# [8 rows x 7 columns]

# %%
new_df.head(100)
# Out:
#      Unnamed: 0  ...                                           Location
# 53           53  ...  {'coordinates': [-87.653996, 41.90715], 'type'...
# 55           55  ...  {'coordinates': [-87.653996, 41.90715], 'type'...
# 57           57  ...  {'coordinates': [-87.653996, 41.90715], 'type'...
# 59           59  ...  {'coordinates': [-87.653996, 41.90715], 'type'...
# 61           61  ...  {'coordinates': [-87.653996, 41.90715], 'type'...
# ..          ...  ...                                                ...
# 243         243  ...  {'coordinates': [-87.653996, 41.90715], 'type'...
# 245         245  ...  {'coordinates': [-87.653996, 41.90715], 'type'...
# 247         247  ...  {'coordinates': [-87.653996, 41.90715], 'type'...
# 249         249  ...  {'coordinates': [-87.653996, 41.90715], 'type'...
# 251         251  ...  {'coordinates': [-87.653996, 41.90715], 'type'...
#
# [100 rows x 17 columns]

# %%
#The data is big and to get the measurement result and also time
#bioswale temperature
new_df = smart_new.loc[(smart_new['Measurement Title'] == 'UI Labs Bioswale - Thunder 1: TM1 Temp Sensor')]
values_df = new_df.iloc[:4, 5]

groupby_Measurement_Title = smart_new.groupby('Measurement Title')
print("Mean by Measurement Value")
print(new_df.mean())

print(values_df.mean())
print("\n")

print("Median by Measurement Value")
print(values_df.median())
print("\n")

print("Skewness by Measurement Value")
df2 = new_df.skew()
df2_transposed = df2.T
print(df2_transposed)
print("\n")
df2 = values_df.skew()
df2_transposed = df2.T
print(df2_transposed)
print("\n")


print("Kurtosis by Measurement Value")
df3 = pd.DataFrame(smart_new)
values2_df = new_df.iloc[:,4 :5]
print(new_df.apply(pd.kurt))
print("\n")
df3 = pd.DataFrame(smart_new)
values2_df = new_df.iloc[:,4 :5]
print(values2_df.apply(pd.kurt))
print("\n")

# %%
#The data is big and to get the measurement result and also time


import pandas as pd
new_df = smart_new.loc[(smart_new['Measurement Title'] == 'UI Labs Bioswale - Thunder 1: TM1 Temp Sensor')]
values_df = new_df.iloc[:, 4:6]

print("Mean by Measurement Value")
print(values_df.mean())
print("\n")

print("Median by Measurement Value")
print(values_df.median())
print("\n")

print("Describe  Measurement Value and Measurement Time")
df1 = values_df[['Measurement Value','Measurement Time']].describe()
df_transposed = df1.T
print(df_transposed)
print("\n")

print("Skewness by Measurement Value")
df2 = value_df.skew()
print(df2)
print("\n")


print("Kurtosis by Measurement Title")
df3 = pd.DataFrame(smart_new)
values2_df = new_df.iloc[:, 4:6]
print(values2_df.groupby('Measurement Value').apply(pd.DataFrame.kurt))
print("\n")
# Out:
# Mean by Measurement Value
# Measurement Value    443.057208
# dtype: float64
#
#
# Median by Measurement Value
# Measurement Value    443.0
# dtype: float64
#
#
# Describe  Measurement Value and Measurement Time
#                       count        mean        std  ...    50%    75%    max
# Measurement Value  553684.0  443.057208  60.259456  ...  443.0  489.0  611.0
#
# [1 rows x 8 columns]
#
#
# Skewness by Measurement Value
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-081884ba6e35> in <module>()
#      21
#      22 print("Skewness by Measurement Value")
# ---> 23 df2 = value_df.skew()
#      24 df2_transposed = df2.T
#      25 print(df2_transposed)
#
# NameError: name 'value_df' is not defined

# %%
#The data is big and to get the measurement result and also time

groupby_Measurement_Title = smart.groupby('Measurement Title')
print("Mean by Measurement Value")
print(smart.mean())
print("\n")

print("Median by Measurement Value")
print(smart.median())
print("\n")

print("Skewness by Measurement Value")
df2 = smart.skew()
df2_transposed = df2.T
print(df2_transposed)
print("\n")


print("Kurtosis by Measurement Value")
df3 = pd.DataFrame(smart)

print(smart.apply(pd.kurt))
print("\n")
# Out:
# Mean by Measurement Value

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

df = pd.DataFrame(data=smart)

df.plot(kind='scatter', x='Measurement Title', y='Measurement Value')
plt.title("A Graph for the value of each sensors for each Sensosr in both UI labs and Argyle locations", fontsize=20)
plt.xlabel("Sensor Name", labelpad=15)
plt.xticks(rotation=90)
plt.ylabel("Sensor Value", labelpad=15)
plt.grid()
plt.show()

# %%
new_df = smart_new.loc[(smart_new['Measurement Title'] == 'UI Labs Bioswale - Thunder 1: TM1 Temp Sensor')]
values_df = new_df.iloc[:, 4:6]
print(values_df.columns)
# The data set contains all the sensor value and time  in one column hence to get the value of the temp sensor

new_RH =smart_new.loc[(smart_new['Measurement Title'] == 'UI Labs Bioswale - Thunder 1: MK-III Weather Station Pressure')]
values_rh = new_df.iloc[:, 4:6]
new_p = smart_new.loc[(smart_new['Measurement Title'] == 'UI Labs Bioswale - Thunder 1: MK-III Weather Station RH')]
values_p = new_df.iloc[:, 4:6]
new_ArP =smart_new.loc[(smart_new['Measurement Title'] == 'Argyle - Thunder 1: MK-III Weather Station Pressur')]
values_ArP = new_df.iloc[:, 4:6]
new_ArT =smart_new.loc[(smart_new['Measurement Title'] == 'Argyle - Thunder 1: MK-III Weather Station Temp')]
values_ArT = new_df.iloc[:, 4:6]
new_ArR =smart_new.loc[(smart_new['Measurement Title'] == 'Argyle - Thunder 1: MK-III Weather Station RH')]
values_ArR = new_df.iloc[:, 4:6]


x = (values_df["Measurement Time"]).values
y1 = (values_df[["Measurement Value"]]).values
y1 = np.reshape(y1,(len(y1),))

y2 = (df_world_var[["coal_consumption"]]).values
y2 = np.reshape(y2,(len(y2),))

y3 = (df_world_var[["oil_consumption"]]).values
y3 = np.reshape(y3,(len(y3),))

y = np.vstack([y1, y2, y3])

labels = ["Gas ", "Coal", "Oil"]

fig, ax = plt.subplots(figsize=(10, 10))
ax.stackplot(x, y1, y2, y3, labels=labels)
ax.legend(loc='upper left')
plt.show()
# Out:
# Index(['Measurement Time', 'Measurement Value'], dtype='object')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-975dfa27e30c> in <module>()
#       3 print(values_df.columns)
#       4
# ----> 5 x = (df_world_var["year"]).values
#       6 y1 = (df_world_var[["gas_consumption"]]).values
#       7 y1 = np.reshape(y1,(len(y1),))
#
# NameError: name 'df_world_var' is not defined

# %% [markdown]
# This Dataset contains Multiple sensor data from three different location I will be using the data for only one place and that place is UI Lab

# %%
# Save the UI lab which is the data of on location in to one csv file to make the analysis easier.

import re
smart_new = smart.loc[smart['Measurement Title'].str.contains('UI Labs', flags=re.I, regex=True)]
#smart_new.to_csv('smartH.csv')

# %%
# The data set contains all the sensor value and time  in one column hence to get the value of the temp sensor

new_df = smart_new.loc[(smart_new['Measurement Title'] == ' MK-III Weather Station Temp     ')]
values_df = new_df.iloc[:, 4:6]
print(values_df.columns)
# Out:
# Index(['Measurement Time', 'Measurement Value'], dtype='object')

# %% [markdown]
# Graph for Temperature in UI lab Bioswale Location from 2017-2018

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

new_df = smart_new.loc[(smart_new['Measurement Title'] == 'UI Labs Bioswale - Thunder 1: TM1 Temp Sensor')]
values_df = new_df.iloc[:, 4:6]

new_df.plot(kind='line', x='Measurement Time', y='Measurement Value', 
        figsize=(10, 8), legend=True, color='green', rot=0);
plt.title("A Graph for the Temp sensort Value from 2017 - 2018", fontsize=20)
plt.xlabel("Date and Time", labelpad=10, fontsize=15)
plt.xticks(rotation=90)
plt.ylabel("Temperature Sensor", labelpad=10, fontsize=15)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-ee94f3e02936> in <module>()
#       4 get_ipython().magic('matplotlib inline')
#       5
# ----> 6 new_df = smart_new.loc[(smart_new['Measurement Title'] == 'UI Labs Bioswale - Thunder 1: TM1 Temp Sensor')]
#       7 values_df = new_df.iloc[:, 4:6]
#       8
#
# NameError: name 'smart_new' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

new_df = smart_new.loc[(smart_new['Measurement Title'] == 'UI Labs Bioswale - Thunder 1: TM1 Temp Sensor')]
values_df = new_df.iloc[:4,6]

new_df.plot(kind='line', x='Measurement Time', y='Measurement Value', 
        figsize=(10, 8), legend=True, color='green', rot=0);
plt.title("A Graph for the Temp sensort Value from 2017 - 2018", fontsize=20)
plt.xlabel("Measurement Time", labelpad=10, fontsize=15)
plt.xticks(rotation=90)
plt.ylabel("Temperature Value", labelpad=10, fontsize=15)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

df = pd.DataFrame(data=smart_new)

df.plot(kind='scatter', x='Measurement Title', y='Measurement Value')
plt.title("A Graph for the value of each sensors for each Sensosr in both UI labs", fontsize=20)
plt.xlabel("Measurement Title", labelpad=15)
plt.xticks(rotation=90)
plt.ylabel("Temperature  Value", labelpad=15)

plt.grid()
plt.show()

# %%
new_df = smart_new.loc[(smart_new['Measurement Title'] == 'UI Labs Bioswale - Thunder 1: TM1 Temp Sensor')]
values_df = new_df.iloc[:4, 6]

new_RH = smart_new.loc[(smart_new['Measurement Title'] == 'UI Labs Bioswale - Thunder 1: MK-III Weather Station RH')]
values_RH = new_df.iloc[:4, 6]

new_df.plot(kind='scatter', x='Measurement Time', y='Measurement Value')

plt.figure(figsize = (10,5))
plt.subplot(1,2,1)
sns.countplot('Measurement Time', hue = 'Measurement Value', data = new_df)

plt.subplot(1,2,2)
sns.countplot('Measurement Time', hue = 'Measurement Value', data = new_RH)

# %%
Inferential

# %% [markdown]
# T-Test

# %%
import pandas as pd
from scipy import stats

smart_new = pd.read_csv('smartH.csv')
smart_new.head()
# Out:
#    Unnamed: 0  ...                                           Location
# 0           0  ...  {'coordinates': [-87.653996, 41.90715], 'type'...
# 1           1  ...  {'coordinates': [-87.653996, 41.90715], 'type'...
# 2           2  ...  {'coordinates': [-87.653996, 41.90715], 'type'...
# 3           3  ...  {'coordinates': [-87.653996, 41.90715], 'type'...
# 4           4  ...  {'coordinates': [-87.653996, 41.90715], 'type'...
#
# [5 rows x 17 columns]

# %%
smart_new = smart_new.drop(['Unnamed: 0'], axis = 1)
new_Temp= smart_new_fraction.loc[(smart_new_fraction['Measurement Title'] == 'UI Labs Bioswale - Thunder 1: TM1 Temp Sensor')]
values_Temp= new_Temp.iloc[:, 6]
new_RH = smart_new_fraction.loc[(smart_new_fraction['Measurement Title'] == 'UI Labs Bioswale - Thunder 1: MK-III Weather Station RH')]
values_RH = new_RH.iloc[:, 6]

# %%
smart_new.head()
# Out:
#                                    Measurement Title  ...                                           Location
# 0  UI Labs Bioswale NWS Probability of Precipitation  ...  {'coordinates': [-87.653996, 41.90715], 'type'...
# 1  UI Labs Bioswale NWS Probability of Precipitation  ...  {'coordinates': [-87.653996, 41.90715], 'type'...
# 2  UI Labs Bioswale NWS Quantitative Precipitatio...  ...  {'coordinates': [-87.653996, 41.90715], 'type'...
# 3  UI Labs Bioswale NWS Quantitative Precipitatio...  ...  {'coordinates': [-87.653996, 41.90715], 'type'...
# 4  UI Labs Bioswale NWS Probability of Precipitation  ...  {'coordinates': [-87.653996, 41.90715], 'type'...
#
# [5 rows x 16 columns]

# %%
values_RH.head()
# Out:
# 3589984    98.0
# 5092739    73.0
# 3686293    59.0
# 4729427    95.0
# 7418820    92.0
# Name: Measurement Value, dtype: float64

# %%
values_Temp.head()
# Out:
# 3937352    444.0
# 5119559    358.0
# 7777005    505.0
# 5264638    407.0
# 412649     490.0
# Name: Measurement Value, dtype: float64

# %%
values_RH.shape
# Out:
# (25066,)

# %%
values_Temp.shape
# Out:
# (46120,)

# %%
t2, p = stats.ttest_ind(values_Temp,values_RH) 

#two-tail 2-sample t-test
alpha_half = 0.005 #alpha is 0.01 or level of confidence is 99%

print("p value = {:g}".format(p))
print("t value = {:g}". format(t2))

if p < alpha_half:  # null hypothesis: x comes from a normal distribution
    print("The null hypothesis can be rejected")
else:
    print("The null hypothesis is accepted")
# Out:
# p value = 0
# t value = 933.655
# The null hypothesis can be rejected

# %%
import re
smart_new = smart.loc[smart['Measurement Title'].str.contains('UI Labs', flags=re.I, regex=True)]

smart_new.to_csv('smartF.csv')

# %%
values_df= smart_new.iloc[:, [0, 4, 5] ]

# %%
values_df.head()
# Out:
#                                    Measurement Title  ... Measurement Value
# 0  UI Labs Bioswale NWS Probability of Precipitation  ...             61.00
# 1  UI Labs Bioswale NWS Probability of Precipitation  ...             61.00
# 2  UI Labs Bioswale NWS Quantitative Precipitatio...  ...              0.30
# 3  UI Labs Bioswale NWS Quantitative Precipitatio...  ...              0.08
# 4  UI Labs Bioswale NWS Probability of Precipitation  ...             59.00
#
# [5 rows x 3 columns]

# %%
values_df.shape
# Out:
# (8074922, 3)

# %%
values_df.to_csv('smartN.csv')

# %%
import re
smart_new_UI = smart.loc[smart['Measurement Title'].str.contains('UI Labs', flags=re.I, regex=True)]
smart_new_UI.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f1554b29300c> in <module>()
#       1 import re
# ----> 2 smart_new_UI = smart.loc[smart['Measurement Title'].str.contains('UI Labs', flags=re.I, regex=True)]
#       3 smart_new_UI.columns
#
# NameError: name 'smart' is not defined

# %%
smart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13299699 entries, 0 to 13299698
# Data columns (total 16 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   Measurement Title        object
#  1   Measurement Description  object
#  2   Measurement Type         object
#  3   Measurement Medium       object
#  4   Measurement Time         object
#  5   Measurement Value        float64
#  6   Units                    object
#  7   Units Abbreviation       object
#  8   Measurement Period Type  object
#  9   Data Stream ID           int64
#  10  Resource ID              int64
#  11  Measurement ID           int64
#  12  Record ID                object
#  13  Latitude                 float64
#  14  Longitude                float64
#  15  Location                 object
# dtypes: float64(3), int64(3), object(10)
# memory usage: 1.6+ GB
# ---------------------------------------------------------------------------
# ...

# %%
smart_new.info()

# %%
smart_new_UI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4168017 entries, 0 to 13247616
# Data columns (total 16 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   Measurement Title        object
#  1   Measurement Description  object
#  2   Measurement Type         object
#  3   Measurement Medium       object
#  4   Measurement Time         object
#  5   Measurement Value        float64
#  6   Units                    object
#  7   Units Abbreviation       object
#  8   Measurement Period Type  object
#  9   Data Stream ID           int64
#  10  Resource ID              int64
#  11  Measurement ID           int64
#  12  Record ID                object
#  13  Latitude                 float64
#  14  Longitude                float64
#  15  Location                 object
# dtypes: float64(3), int64(3), object(10)
# memory usage: 540.6+ MB

# %%
smart_new_UI.isnull().any() #checks if there is any null value which will return true....since we have to replace or remove when designing our model
smart_new_UI.isnull().any()
smart_new_UI.isnull().any()
# Out:
# Measurement Title          False
# Measurement Description     True
# Measurement Type           False
# Measurement Medium          True
# Measurement Time           False
# Measurement Value          False
# Units                      False
# Units Abbreviation         False
# Measurement Period Type    False
# Data Stream ID             False
# Resource ID                False
# Measurement ID             False
# Record ID                  False
# Latitude                   False
# Longitude                  False
# Location                   False
# dtype: bool

# %%
#Now check if all the cvalue in that colun are null
smart_new_UI.isnull().all()
smart_new_UI.isnull().all()
# Out:
# Measurement Title          False
# Measurement Description    False
# Measurement Type           False
# Measurement Medium         False
# Measurement Time           False
# Measurement Value          False
# Units                      False
# Units Abbreviation         False
# Measurement Period Type    False
# Data Stream ID             False
# Resource ID                False
# Measurement ID             False
# Record ID                  False
# Latitude                   False
# Longitude                  False
# Location                   False
# dtype: bool

# %%
smart_new['Measurement Value'].value_counts()
smart_new_UI['Measurement Value'].value_counts()
# Out:
# 0.0       248060
# 45.0       55957
# 270.0      55757
# 315.0      39682
# 90.0       38526
#            ...
# 1709.0         1
# 3569.0         1
# 3565.0         1
# 3564.0         1
# 1402.0         1
# Name: Measurement Value, Length: 6088, dtype: int64

# %%
Descriptive Statistics of UI lab only form Final.xlsx

# %%
import pandas as pd
dataset = pd.read_excel('final.xlsx')

# %%
import matplotlib.pyplot as plt

# %matplotlib inline


dataset.plot(kind='scatter', x='Time', y='Temperature', 
        figsize=(10, 8), legend=True, color='green');
plt.title("A Graph for the Temp senso Value from 2017 - 2018", fontsize=20)
plt.xlabel("Date and Time", labelpad=10, fontsize=15)
plt.xticks(rotation=90)
plt.ylabel("Temperature ", labelpad=10, fontsize=15)

plt.show()

# %%
dataset.describe()
# Out:
#         Temperature            RH  ...  Wind Direction      Rainfall
# count  43822.000000  43822.000000  ...    43822.000000  43822.000000
# mean      61.195769     74.000434  ...      241.540003   5776.382662
# std       50.572409     21.260745  ...       93.700305   1049.528727
# min      -63.000000      0.000000  ...        0.000000      0.000000
# 25%       30.000000     60.000000  ...      225.000000   5647.000000
# 50%       57.000000     72.000000  ...      270.000000   5778.000000
# 75%       87.000000     86.000000  ...      292.000000   5808.000000
# max      262.000000    198.000000  ...      720.000000  11914.000000
#
# [8 rows x 6 columns]

# %%
print("Median  Temperature")
print(dataset["Temperature"].median())

print("\n")
print("mean value of measurement value")
print(dataset["Temperature"].mean())

print("\n")
print("Aggregated descriptive functions")
print(dataset.agg({'Temperature': ['min', 'mean', 'max', 'median', 'skew'],
             'Temperature': ['min', 'max', 'median', 'mean', 'skew']
             }
             )
)
# Out:
# Median  Temperature
# 57.0
#
#
# mean value of measurement value
# 61.19576924832276
#
#
# Aggregated descriptive functions
#         Temperature
# min      -63.000000
# max      262.000000
# median    57.000000
# mean      61.195769
# skew       0.753123
