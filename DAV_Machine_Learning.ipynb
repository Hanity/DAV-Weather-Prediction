# %%
import pandas as pd 
import numpy as np 
import sklearn 
from sklearn.model_selection import train_test_split 
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
import matplotlib.pyplot as plt 
import seaborn as sb 
from sklearn import preprocessing

# %%
dataset= pd.read_excel("final.xlsx")

# %%
print("Data heads:") 
print(data.head()) 
print("Null values in the dataset before preprocessing:") 
print(data.isnull().sum()) 
print("Filling null values with mean of that particular column") 
data=data.fillna(np.mean(data)) 
print("Mean of data:") 
print(np.mean(data)) 
print("Null values in the dataset after preprocessing:") 
print(data.isnull().sum()) 
print("\n\nShape: ",data.shape)
# Out:
# Data heads:
#                       Time  Temperature  ...  Wind Direction  Rainfall
# 0  2017-10-21T09:22:54.000          262  ...             292      5367
# 1  2017-10-21T09:23:55.000          262  ...             315      5367
# 2  2017-10-21T09:24:56.000          262  ...             270      5367
# 3  2017-10-21T09:25:59.000          262  ...             315      5367
# 4  2017-10-21T09:27:02.000          261  ...             292      5367
#
# [5 rows x 7 columns]
# Null values in the dataset before preprocessing:
# Time              0
# Temperature       0
# RH                0
# Pressure          0
# Wind Speed        0
# Wind Direction    0
# Rainfall          0
# dtype: int64
# Filling null values with mean of that particular column
# Mean of data:
# Temperature          61.195769
# RH                   74.000434
# Pressure          10079.035941
# Wind Speed            9.568915
# Wind Direction      241.540003
# Rainfall           5776.382662
# dtype: float64
# Null values in the dataset after preprocessing:
# Time              0
# Temperature       0
# RH                0
# Pressure          0
# Wind Speed        0
# Wind Direction    0
# Rainfall          0
# dtype: int64
#
#
# Shape:  (43822, 7)

# %%
print("Info:") 
print(data.info())
# Out:
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43822 entries, 0 to 43821
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Time            43822 non-null  object
#  1   Temperature     43822 non-null  int64
#  2   RH              43822 non-null  int64
#  3   Pressure        43822 non-null  int64
#  4   Wind Speed      43822 non-null  int64
#  5   Wind Direction  43822 non-null  int64
#  6   Rainfall        43822 non-null  int64
# dtypes: int64(6), object(1)
# memory usage: 2.3+ MB
# None

# %%
from sklearn import linear_model
print('__Multiple Linear regression model between annual rainfall and the periodic rainfall__')

y=data['Rainfall']
x=data[['Temperature']]
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.3,shuffle=False)
'''train_x=train_x[:,np.newaxis]
test_x=test_x[:,np.newaxis]'''
print("Train x shape",train_x.shape,"; Test_x",test_x.shape)
print("Train y shape",train_y.shape,"; Test_y",test_y.shape)
lm=linear_model.LinearRegression()
lm.fit(train_x,train_y)
pred=lm.predict(test_x)
print(test_y)
print(pred)
print("Mean Squared Error =",mean_squared_error(test_y,pred))
print("Root Mean Squared Error =",np.sqrt(mean_squared_error(test_y,pred)))
print("Mean Absolute Error =",mean_absolute_error(test_y,pred))
print("r2_score =",r2_score(test_y,pred))
plt.scatter(pred,test_y)
plt.xlabel('TRAIN_X')
plt.ylabel('TRAIN_Y')
plt.show()
# Out:
# __Multiple Linear regression model between annual rainfall and the periodic rainfall__
# Train x shape (30675, 1) ; Test_x (13147, 1)
# Train y shape (30675,) ; Test_y (13147,)
# 30675    5808
# 30676    5808
# 30677    5808
# 30678    5808
# 30679    5808
#          ...
# 43817    5962
# 43818    5962
# 43819    5962
# 43820    5962
# 43821    5962
# Name: Rainfall, Length: 13147, dtype: int64
# [5800.43406948 5800.43406948 5800.43406948 ... 6047.88817373 6047.88817373
#  6047.88817373]
# Mean Squared Error = 3613457.5758722764
# Root Mean Squared Error = 1900.9096706241137
# Mean Absolute Error = 640.5176510416715
# r2_score = -0.014533026857923348

# %%
from sklearn import linear_model
print('__Multiple Linear regression model between Rainfall and RH__')

y=data['Rainfall']
x=data[['RH']]
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.3,shuffle=False)
'''train_x=train_x[:,np.newaxis]
test_x=test_x[:,np.newaxis]'''
print("Train x shape",train_x.shape,"; Test_x",test_x.shape)
print("Train y shape",train_y.shape,"; Test_y",test_y.shape)
lm=linear_model.LinearRegression()
lm.fit(train_x,train_y)
pred=lm.predict(test_x)
print(test_y)
print(pred)
print("Mean Squared Error =",mean_squared_error(test_y,pred))
print("Root Mean Squared Error =",np.sqrt(mean_squared_error(test_y,pred)))
print("Mean Absolute Error =",mean_absolute_error(test_y,pred))
print("r2_score =",r2_score(test_y,pred))
plt.scatter(pred,test_y)
plt.xlabel('TRAIN_X')
plt.ylabel('TRAIN_Y')
plt.show()
# Out:
# __Multiple Linear regression model between Rainfall and RH__
# Train x shape (30675, 1) ; Test_x (13147, 1)
# Train y shape (30675,) ; Test_y (13147,)
# 30675    5808
# 30676    5808
# 30677    5808
# 30678    5808
# 30679    5808
#          ...
# 43817    5962
# 43818    5962
# 43819    5962
# 43820    5962
# 43821    5962
# Name: Rainfall, Length: 13147, dtype: int64
# [5674.95679786 5674.95679786 5674.95679786 ... 5673.75327459 5673.75327459
#  5673.75327459]
# Mean Squared Error = 3674671.387736092
# Root Mean Squared Error = 1916.9432406141011
# Mean Absolute Error = 801.9223865938193
# r2_score = -0.03171973308920273

# %% [markdown]
# Multivariate Polynomial Regression

# %%
#Multivariate Polynomial Regression
#https://towardsdatascience.com/machine-learning-polynomial-regression-with-python-5328e4e8a386
#https://stackoverflow.com/questions/51281684/multivariate-polynomial-regression-for-python
#https://stats.stackexchange.com/questions/449413/polynomial-regression-seems-to-give-different-coefficients-depending-on-python-o
#https://acadgild.com/blog/polynomial-regression-understand-power-of-polynomials

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
import statsmodels.api as sm
import statsmodels.formula.api as smf
from mpl_toolkits import mplot3d


# Load the dataset
dataset = pd.read_excel('final.xlsx')
                     
print(dataset.head())
print("\n")

#Selection of Predictors for the Model
#In this example, we shall choose several columns as predictors
#Columns 0 and 13 as predictors
#Column 14 as the target variable
X = dataset[['Temperature', 'RH']]
X1 = dataset['Temperature']
X2 = dataset['RH']
y = dataset['Rainfall']


#Split Dataset to Train and Test Dataset
x_train, x_test, y_train, y_test = train_test_split(X,y,test_size=0.10, random_state=42)
X11 = x_test['Temperature']
X12 = x_test['RH']
print('X test :')
print(x_test)
print("\n")
print('X test Temperature :')
print(X11)
print("\n")
print('X test RH :')
print(X12)
print("\n")                                                                          

#Train and Fit the model with nth degree
#https://acadgild.com/blog/polynomial-regression-understand-power-of-polynomials

#Plot x test and y test - 3D plot
#https://scipy-lectures.org/packages/statistics/auto_examples/plot_regression_3d.html
fig = plt.figure(figsize = (30,10))
ax = fig.add_subplot(1,2,1, projection = '3d')
ax.scatter3D(X1, X2, y, c=y, cmap='Greens')
ax.plot3D(X1, X2, y, 'gray')

#Second subplot
# set up the axes for the second plot
ax = fig.add_subplot(1, 2, 2, projection='3d')
ax.plot_trisurf(X1, X2, y, cmap=plt.cm.viridis, linewidth=0.2)
plt.show()
ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('y')


#Build the model
ax = fig.add_subplot(2, 2, 1, projection='3d')
for degree in [1,2,3,4,5,6,7]:
    model = make_pipeline(PolynomialFeatures(degree), LinearRegression())
    model.fit(x_train,y_train)
    y_pred = model.predict(x_test)
    print("Return the coefficient of determination R^2 of the prediction, i.e. the model score is: ",model.score(x_test, y_test))
    print("\n")
    plt.plot(y_test, y_pred, label="degree %d" % degree)
    plt.legend(loc='upper right')
plt.xlabel("Test Rainfall Data")
plt.ylabel("Predicted Rainfall")
# Out:
#                       Time  Temperature  ...  Wind Direction  Rainfall
# 0  2017-10-21T09:22:54.000          262  ...             292      5367
# 1  2017-10-21T09:23:55.000          262  ...             315      5367
# 2  2017-10-21T09:24:56.000          262  ...             270      5367
# 3  2017-10-21T09:25:59.000          262  ...             315      5367
# 4  2017-10-21T09:27:02.000          261  ...             292      5367
#
# [5 rows x 7 columns]
#
#
# X test :
#        Temperature  RH
# 9267            93  77
# 6482           106  84
# 29036           38  63
# 18555           66  72
# 7650           100  56
# ...            ...  ..
# 12075           85  54
# 35992           21  76
# 33983           28  94
# 10163           90  62
# 18553           66  73
#
# [4383 rows x 2 columns]
#
#
# X test Temperature :
# 9267      93
# 6482     106
# 29036     38
# 18555     66
# 7650     100
#         ...
# 12075     85
# 35992     21
# 33983     28
# 10163     90
# 18553     66
# Name: Temperature, Length: 4383, dtype: int64
#
#
# X test RH :
# 9267     77
# 6482     84
# 29036    63
# 18555    72
# 7650     56
#          ..
# 12075    54
# 35992    76
# 33983    94
# 10163    62
# 18553    73
# Name: RH, Length: 4383, dtype: int64
# Return the coefficient of determination R^2 of the prediction, i.e. the model score is:  0.33340912643746967
#
#
# Return the coefficient of determination R^2 of the prediction, i.e. the model score is:  0.5043630986514324
#
#
# Return the coefficient of determination R^2 of the prediction, i.e. the model score is:  0.5381279991409438
#
#
# Return the coefficient of determination R^2 of the prediction, i.e. the model score is:  0.6505988580598796
#
#
# Return the coefficient of determination R^2 of the prediction, i.e. the model score is:  0.6863537928550316
#
#
# Return the coefficient of determination R^2 of the prediction, i.e. the model score is:  0.6969729120745003
#
#
# Return the coefficient of determination R^2 of the prediction, i.e. the model score is:  0.7021011448463599
# Text(0, 0.5, 'Predicted Rainfall')

# %% [markdown]
# Polynomial Regression

# %%
#Polynomial Regression
#https://online.stat.psu.edu/stat501/lesson/9/9.8
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
import statsmodels.api as sm
import statsmodels.formula.api as smf

#Selection of Predictors for the Model
#In this example, we shall choose columns 1 and 2 variables as predictors
#Columns 1 and 2 
X = dataset[['Temperature']] #because it is 1-D
X1 = dataset['Temperature']
y = dataset['RH']

#Plot graphs
#fig, ax = plt.subplots(1,2, figsize = (10,5))
#sns.scatterplot(data = dataset, x=X, y=y, ax = ax[0])
#sns.regplot(data = dataset, x=X, y=y, ax = ax[1])
#sns.lmplot(x="Temperature", y="RH", data=dataset)
#sns.lmplot(x="Temperature", y="RH", data=dataset, order = 2) # order = 2 - quadratic
#fig = plt.figure()


#Polynomial Regression Model
poly_reg = PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(X)
pol_reg = LinearRegression()
model = pol_reg.fit(X_poly, y)

y_pred = model.predict(X_poly)
print(y_pred)
print("\n")

#Model Summary
reg_label = "Coefficients:%s - b:%0.2f" % \
            (np.array2string(model.coef_,
                             formatter={'float_kind': lambda fk: "%.3f" % fk}),
            model.intercept_)
print(reg_label)
print("\n")
print("The model coefficients are: for degree 4 - x^0, x^1, x^2, x^3, X^4 ")
print(model.coef_)
print("The model intercepts are ", model.intercept_)
print("\n")



#Visualise Pre Polynomial Regression Graphs
fig, ax = plt.subplots(1,2, figsize = (10,5))
sns.scatterplot(data=dataset, x = "Temperature", y = "RH", ax = ax[0])
sns.regplot(data = dataset, x = "Temperature", y = "RH", ax = ax[1])
sns.lmplot(x="Temperature", y="RH", data=dataset)
sns.lmplot(x="Temperature", y="RH", data=dataset, order = 2) # order = 2 - quadratic

#Visualise Polynomial Regression Graphs
fig1, ax1 = plt.subplots()
ax1.scatter(X1,y, color = 'green')
ax1.plot(X1, y_pred, color = 'red')
ax1.scatter(X1, y_pred, color = 'black', marker = 'x')
ax1.set_title("Polynomial Regression Model Plot")
ax1.set_xlabel("Temperature")
ax1.set_ylabel("RH")

#Use Statsmodel
### STATSMODELS ###

# create a fitted model with all three features
lm1 = smf.ols(formula='RH ~ Temperature + Temperature^2 + Temperature^3 + Temperature^4', data=dataset).fit()

# print the coefficients using statsmodel
print("Coefficients using statsmodel")
print(lm1.params)
print("\n")


#Print coefficients using scikit-LEarn
#Look at model symmary above
print("Coefficients using SK-Learn Polynomial Regression Model ")
print("The model coefficients are: for degree 4 - x^0, x^1, x^2, x^3, X^4 ")
print(model.coef_)
print("The model intercepts are ", model.intercept_)
print("Compare the results of statsmodel and sk-learn for polynomial regression model")
print("\n")

#Model Evaluation
# calculate MAE, MSE, RMSE
print('Mean Absolute Error, MAE is ', metrics.mean_absolute_error(y, y_pred))
print('Mean Squared Error, MSE is ', metrics.mean_squared_error(y, y_pred))
print('Root Mean Square Error is ', np.sqrt(metrics.mean_squared_error(y, y_pred)))
print("\n")

#Rsquared value of model
print("Coefficient of determination or R squared value is ")
print(r2_score(y, y_pred))
print("\n")
# Out:
# [32.47156168 32.47156168 32.47156168 ... 36.33470381 36.33470381
#  36.33470381]
#
#
# Coefficients:[0.000 0.177 -0.004 0.000 -0.000] - b:72.60
#
#
# The model coefficients are: for degree 4 - x^0, x^1, x^2, x^3, X^4
# [ 0.00000000e+00  1.76879988e-01 -3.90955846e-03  3.29252491e-05
#  -8.70659191e-08]
# The model intercepts are  72.59958640657635
#
#
# Coefficients using statsmodel
# Intercept          71.919848
# Temperature        -0.226494
# Temperature ^ 2     0.652043
# Temperature ^ 3    -0.714228
# Temperature ^ 4     0.322499
# dtype: float64
#
#
# Coefficients using SK-Learn Polynomial Regression Model
# The model coefficients are: for degree 4 - x^0, x^1, x^2, x^3, X^4
# [ 0.00000000e+00  1.76879988e-01 -3.90955846e-03  3.29252491e-05
#  -8.70659191e-08]
# The model intercepts are  72.59958640657635
# Compare the results of statsmodel and sk-learn for polynomial regression model
#
#
# Mean Absolute Error, MAE is  14.62411818085839
# Mean Squared Error, MSE is  423.9842738764825
# Root Mean Square Error is  20.590878414397054
#
#
# Coefficient of determination or R squared value is
# 0.06200030535525547

# %%
#Polynomial Regression
#https://online.stat.psu.edu/stat501/lesson/9/9.8
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
import statsmodels.api as sm
import statsmodels.formula.api as smf

#Selection of Predictors for the Model
#In this example, we shall choose columns 1 and 2 variables as predictors
#Columns 1 and 2 
X = dataset[['Temperature']] #because it is 1-D
X1 = dataset['Temperature']
y = dataset['Rainfall']

#Plot graphs
#fig, ax = plt.subplots(1,2, figsize = (10,5))
#sns.scatterplot(data = dataset, x=X, y=y, ax = ax[0])
#sns.regplot(data = dataset, x=X, y=y, ax = ax[1])
#sns.lmplot(x="Temperature", y="Rainfall", data=dataset)
#sns.lmplot(x="Temperature", y="Rainfall", data=dataset, order = 2) # order = 2 - quadratic
#fig = plt.figure()


#Polynomial Regression Model
poly_reg = PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(X)
pol_reg = LinearRegression()
model = pol_reg.fit(X_poly, y)

y_pred = model.predict(X_poly)
print(y_pred)
print("\n")

#Model Summary
reg_label = "Coefficients:%s - b:%0.2f" % \
            (np.array2string(model.coef_,
                             formatter={'float_kind': lambda fk: "%.3f" % fk}),
            model.intercept_)
print(reg_label)
print("\n")
print("The model coefficients are: for degree 4 - x^0, x^1, x^2, x^3, X^4 ")
print(model.coef_)
print("The model intercepts are ", model.intercept_)
print("\n")



#Visualise Pre Polynomial Regression Graphs
fig, ax = plt.subplots(1,2, figsize = (10,5))
sns.scatterplot(data=dataset, x = "Temperature", y = "Rainfall", ax = ax[0])
sns.regplot(data = dataset, x = "Temperature", y = "Rainfall", ax = ax[1])
sns.lmplot(x="Temperature", y="Rainfall", data=dataset)
sns.lmplot(x="Temperature", y="Rainfall", data=dataset, order = 2) # order = 2 - quadratic

#Visualise Polynomial Regression Graphs
fig1, ax1 = plt.subplots()
ax1.scatter(X1,y, color = 'green')
ax1.plot(X1, y_pred, color = 'red')
ax1.scatter(X1, y_pred, color = 'black', marker = 'x')
ax1.set_title("Polynomial Regression Model Plot")
ax1.set_xlabel("Temperature")
ax1.set_ylabel("Rainfall")

#Use Statsmodel
### STATSMODELS ###

# create a fitted model with all three features
lm1 = smf.ols(formula='Rainfall ~ Temperature + Temperature^2 + Temperature^3 + Temperature^4', data=dataset).fit()

# print the coefficients using statsmodel
print("Coefficients using statsmodel")
print(lm1.params)
print("\n")


#Print coefficients using scikit-LEarn
#Look at model symmary above
print("Coefficients using SK-Learn Polynomial Regression Model ")
print("The model coefficients are: for degree 4 - x^0, x^1, x^2, x^3, X^4 ")
print(model.coef_)
print("The model intercepts are ", model.intercept_)
print("Compare the results of statsmodel and sk-learn for polynomial regression model")
print("\n")

#Model Evaluation
# calculate MAE, MSE, RMSE
print('Mean Absolute Error, MAE is ', metrics.mean_absolute_error(y, y_pred))
print('Mean Squared Error, MSE is ', metrics.mean_squared_error(y, y_pred))
print('Root Mean Square Error is ', np.sqrt(metrics.mean_squared_error(y, y_pred)))
print("\n")

#Rsquared value of model
print("Coefficient of determination or R squared value is ")
print(r2_score(y, y_pred))
print("\n")
# Out:
# [5232.27151026 5232.27151026 5232.27151026 ... 5218.89391036 5218.89391036
#  5218.89391036]
#
#
# Coefficients:[0.000 1.384 -0.119 0.001 -0.000] - b:6003.00
#
#
# The model coefficients are: for degree 4 - x^0, x^1, x^2, x^3, X^4
# [ 0.00000000e+00  1.38434821e+00 -1.19135599e-01  7.98233582e-04
#  -1.55167570e-06]
# The model intercepts are  6002.996439272726
#
#
# Coefficients using statsmodel
# Intercept          5942.059025
# Temperature           0.505464
# Temperature ^ 2      76.378174
# Temperature ^ 3     -76.011821
# Temperature ^ 4      -3.556442
# dtype: float64
#
#
# Coefficients using SK-Learn Polynomial Regression Model
# The model coefficients are: for degree 4 - x^0, x^1, x^2, x^3, X^4
# [ 0.00000000e+00  1.38434821e+00 -1.19135599e-01  7.98233582e-04
#  -1.55167570e-06]
# The model intercepts are  6002.996439272726
# Compare the results of statsmodel and sk-learn for polynomial regression model
#
#
# Mean Absolute Error, MAE is  263.7463424477426
# Mean Squared Error, MSE is  1067528.018526501
# Root Mean Square Error is  1033.2124750149414
#
#
# Coefficient of determination or R squared value is
# 0.03082872752469945

# %%
#Polynomial Regression
#https://online.stat.psu.edu/stat501/lesson/9/9.8
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
import statsmodels.api as sm
import statsmodels.formula.api as smf

#Selection of Predictors for the Model
#In this example, we shall choose columns 1 and 2 variables as predictors
#Columns 1 and 2 
X = dataset[['Wind Speed']] #because it is 1-D
X1 = dataset['Wind Speed']
y = dataset['Wind Direction']

#Plot graphs
#fig, ax = plt.subplots(1,2, figsize = (10,5))
#sns.scatterplot(data = dataset, x=X, y=y, ax = ax[0])
#sns.regplot(data = dataset, x=X, y=y, ax = ax[1])
#sns.lmplot(x="Wind Speed", y="Wind Direction", data=dataset)
#sns.lmplot(x="Wind Speed", y="Wind Direction", data=dataset, order = 2) # order = 2 - quadratic
#fig = plt.figure()


#Polynomial Regression Model
poly_reg = PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(X)
pol_reg = LinearRegression()
model = pol_reg.fit(X_poly, y)

y_pred = model.predict(X_poly)
print(y_pred)
print("\n")

#Model Summary
reg_label = "Coefficients:%s - b:%0.2f" % \
            (np.array2string(model.coef_,
                             formatter={'float_kind': lambda fk: "%.3f" % fk}),
            model.intercept_)
print(reg_label)
print("\n")
print("The model coefficients are: for degree 4 - x^0, x^1, x^2, x^3, X^4 ")
print(model.coef_)
print("The model intercepts are ", model.intercept_)
print("\n")



#Visualise Pre Polynomial Regression Graphs
fig, ax = plt.subplots(1,2, figsize = (10,5))

sns.regplot(data = dataset, x = "Wind Speed", y = "Wind Direction", ax = ax[1])
sns.lmplot(x="Wind Speed", y="Wind Direction", data=dataset)
sns.lmplot(x="Wind Speed", y="Wind Direction", data=dataset, order = 2) # order = 2 - quadratic

#Visualise Polynomial Regression Graphs
fig1, ax1 = plt.subplots()
ax1.scatter(X1,y, color = 'green')
ax1.plot(X1, y_pred, color = 'red')
ax1.scatter(X1, y_pred, color = 'black', marker = 'x')
ax1.set_title("Polynomial Regression Model Plot")
ax1.set_xlabel("Wind Speed")
ax1.set_ylabel("Wind Direction")

#Use Statsmodel
### STATSMODELS ###

# create a fitted model with all three features
lm1 = smf.ols(formula='Wind Direction ~ Wind Speed + Wind Speed^2 + Wind Speed^3 + Wind Speed^4', data=dataset).fit()

# print the coefficients using statsmodel
print("Coefficients using statsmodel")
print(lm1.params)
print("\n")


#Print coefficients using scikit-LEarn
#Look at model symmary above
print("Coefficients using SK-Learn Polynomial Regression Model ")
print("The model coefficients are: for degree 4 - x^0, x^1, x^2, x^3, X^4 ")
print(model.coef_)
print("The model intercepts are ", model.intercept_)
print("Compare the results of statsmodel and sk-learn for polynomial regression model")
print("\n")

#Model Evaluation
# calculate MAE, MSE, RMSE
print('Mean Absolute Error, MAE is ', metrics.mean_absolute_error(y, y_pred))
print('Mean Squared Error, MSE is ', metrics.mean_squared_error(y, y_pred))
print('Root Mean Square Error is ', np.sqrt(metrics.mean_squared_error(y, y_pred)))
print("\n")

#Rsquared value of model
print("Coefficient of determination or R squared value is ")
print(r2_score(y, y_pred))
print("\n")
# Out:
# [241.48287009 243.73751121 227.44915857 ... 231.35339756 240.31448033
#  233.39569139]
#
#
# Coefficients:[0.000 -0.449 -0.070 0.002 -0.000] - b:249.50
#
#
# The model coefficients are: for degree 4 - x^0, x^1, x^2, x^3, X^4
# [ 0.00000000e+00 -4.49298386e-01 -6.95470046e-02  2.42134768e-03
#  -1.56683653e-05]
# The model intercepts are  249.49750062419076
#   File "<unknown>", line 1
#     Wind Speed ^ 3
#              ^
# SyntaxError: invalid syntax

# %%
#Polynomial Regression
#https://online.stat.psu.edu/stat501/lesson/9/9.8
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
import statsmodels.api as sm
import statsmodels.formula.api as smf

#Selection of Predictors for the Model
#In this example, we shall choose columns 1 and 2 variables as predictors
#Columns 1 and 2 
X = dataset[['RH']] #because it is 1-D
X1 = dataset['RH']
y = dataset['Rainfall']

#Plot graphs
#fig, ax = plt.subplots(1,2, figsize = (10,5))
#sns.scatterplot(data = dataset, x=X, y=y, ax = ax[0])
#sns.regplot(data = dataset, x=X, y=y, ax = ax[1])
#sns.lmplot(x="RH", y="RH", data=dataset)
#sns.lmplot(x="RH", y="RH", data=dataset, order = 2) # order = 2 - quadratic
#fig = plt.figure()


#Polynomial Regression Model
poly_reg = PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(X)
pol_reg = LinearRegression()
model = pol_reg.fit(X_poly, y)

y_pred = model.predict(X_poly)
print(y_pred)
print("\n")

#Model Summary
reg_label = "Coefficients:%s - b:%0.2f" % \
            (np.array2string(model.coef_,
                             formatter={'float_kind': lambda fk: "%.3f" % fk}),
            model.intercept_)
print(reg_label)
print("\n")
print("The model coefficients are: for degree 4 - x^0, x^1, x^2, x^3, X^4 ")
print(model.coef_)
print("The model intercepts are ", model.intercept_)
print("\n")



#Visualise Pre Polynomial Regression Graphs
fig, ax = plt.subplots(1,2, figsize = (10,5))
sns.scatterplot(data=dataset, x = "RH", y = "Rainfall", ax = ax[0])
sns.regplot(data = dataset, x = "RH", y = "Rainfall", ax = ax[1])
sns.lmplot(x="RH", y="Rainfall", data=dataset)
sns.lmplot(x="RH", y="Rainfall", data=dataset, order = 2) # order = 2 - quadratic

#Visualise Polynomial Regression Graphs
fig1, ax1 = plt.subplots()
ax1.scatter(X1,y, color = 'green')
ax1.plot(X1, y_pred, color = 'red')
ax1.scatter(X1, y_pred, color = 'black', marker = 'x')
ax1.set_title("Polynomial Regression Model Plot")
ax1.set_xlabel("RH")
ax1.set_ylabel("Rainfall")

#Use Statsmodel
### STATSMODELS ###

# create a fitted model with all three features
lm1 = smf.ols(formula='RH ~ RH + RH^2 + RH^3 + RH^4', data=dataset).fit()

# print the coefficients using statsmodel
print("Coefficients using statsmodel")
print(lm1.params)
print("\n")


#Print coefficients using scikit-LEarn
#Look at model symmary above
print("Coefficients using SK-Learn Polynomial Regression Model ")
print("The model coefficients are: for degree 4 - x^0, x^1, x^2, x^3, X^4 ")
print(model.coef_)
print("The model intercepts are ", model.intercept_)
print("Compare the results of statsmodel and sk-learn for polynomial regression model")
print("\n")

#Model Evaluation
# calculate MAE, MSE, RMSE
print('Mean Absolute Error, MAE is ', metrics.mean_absolute_error(y, y_pred))
print('Mean Squared Error, MSE is ', metrics.mean_squared_error(y, y_pred))
print('Root Mean Square Error is ', np.sqrt(metrics.mean_squared_error(y, y_pred)))
print("\n")

#Rsquared value of model
print("Coefficient of determination or R squared value is ")
print(r2_score(y, y_pred))
print("\n")
# Out:
# [5685.76195534 5685.76195534 5685.76195534 ... 5720.51438655 5720.51438655
#  5720.51438655]
#
#
# Coefficients:[0.000 334.582 -6.620 0.052 -0.000] - b:-65.98
#
#
# The model coefficients are: for degree 4 - x^0, x^1, x^2, x^3, X^4
# [ 0.00000000e+00  3.34581922e+02 -6.61987339e+00  5.16938384e-02
#  -1.27893029e-04]
# The model intercepts are  -65.98455487017236
#
#
# Coefficients using statsmodel
# Intercept    3.904134e-13
# RH           1.000000e+00
# RH ^ 2       1.983179e-14
# RH ^ 3       4.377141e-15
# RH ^ 4      -8.976652e-15
# dtype: float64
#
#
# Coefficients using SK-Learn Polynomial Regression Model
# The model coefficients are: for degree 4 - x^0, x^1, x^2, x^3, X^4
# [ 0.00000000e+00  3.34581922e+02 -6.61987339e+00  5.16938384e-02
#  -1.27893029e-04]
# The model intercepts are  -65.98455487017236
# Compare the results of statsmodel and sk-learn for polynomial regression model
#
#
# Mean Absolute Error, MAE is  234.90677160515165
# Mean Squared Error, MSE is  368288.03424251557
# Root Mean Square Error is  606.8673942819103
#
#
# Coefficient of determination or R squared value is
# 0.6656442017541433

# %%
#Polynomial Regression
#https://online.stat.psu.edu/stat501/lesson/9/9.8
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
import statsmodels.api as sm
import statsmodels.formula.api as smf

#Selection of Predictors for the Model
#In this example, we shall choose columns 1 and 2 variables as predictors
#Columns 1 and 2 
X = dataset[['Pressure']] #because it is 1-D
X1 = dataset['Pressure']
y = dataset['Rainfall']

#Plot graphs
#fig, ax = plt.subplots(1,2, figsize = (10,5))
#sns.scatterplot(data = dataset, x=X, y=y, ax = ax[0])
#sns.regplot(data = dataset, x=X, y=y, ax = ax[1])
#sns.lmplot(x="Pressure", y="Pressure", data=dataset)
#sns.lmplot(x="Pressure", y="Pressure", data=dataset, order = 2) # order = 2 - quadratic
#fig = plt.figure()


#Polynomial Regression Model
poly_reg = PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(X)
pol_reg = LinearRegression()
model = pol_reg.fit(X_poly, y)

y_pred = model.predict(X_poly)
print(y_pred)
print("\n")

#Model Summary
reg_label = "Coefficients:%s - b:%0.2f" % \
            (np.array2string(model.coef_,
                             formatter={'float_kind': lambda fk: "%.3f" % fk}),
            model.intercept_)
print(reg_label)
print("\n")
print("The model coefficients are: for degree 4 - x^0, x^1, x^2, x^3, X^4 ")
print(model.coef_)
print("The model intercepts are ", model.intercept_)
print("\n")



#Visualise Pre Polynomial Regression Graphs
fig, ax = plt.subplots(1,2, figsize = (10,5))
sns.scatterplot(data=dataset, x = "Pressure", y = "Rainfall", ax = ax[0])
sns.regplot(data = dataset, x = "Pressure", y = "Rainfall", ax = ax[1])
sns.lmplot(x="Pressure", y="Rainfall", data=dataset)
sns.lmplot(x="Pressure", y="Rainfall", data=dataset, order = 2) # order = 2 - quadratic

#Visualise Polynomial Regression Graphs
fig1, ax1 = plt.subplots()
ax1.scatter(X1,y, color = 'green')
ax1.plot(X1, y_pred, color = 'red')
ax1.scatter(X1, y_pred, color = 'black', marker = 'x')
ax1.set_title("Polynomial Regression Model Plot")
ax1.set_xlabel("Pressure")
ax1.set_ylabel("Rainfall")

#Use Statsmodel
### STATSMODELS ###

# create a fitted model with all three features
lm1 = smf.ols(formula='Pressure ~ Pressure + Pressure^2 + Pressure^3 + Pressure^4', data=dataset).fit()

# print the coefficients using statsmodel
print("Coefficients using statsmodel")
print(lm1.params)
print("\n")


#Print coefficients using scikit-LEarn
#Look at model symmary above
print("Coefficients using SK-Learn Polynomial Regression Model ")
print("The model coefficients are: for degree 4 - x^0, x^1, x^2, x^3, X^4 ")
print(model.coef_)
print("The model intercepts are ", model.intercept_)
print("Compare the results of statsmodel and sk-learn for polynomial regression model")
print("\n")

#Model Evaluation
# calculate MAE, MSE, RMSE
print('Mean Absolute Error, MAE is ', metrics.mean_absolute_error(y, y_pred))
print('Mean Squared Error, MSE is ', metrics.mean_squared_error(y, y_pred))
print('Root Mean Square Error is ', np.sqrt(metrics.mean_squared_error(y, y_pred)))
print("\n")

#Rsquared value of model
print("Coefficient of determination or R squared value is ")
print(r2_score(y, y_pred))
print("\n")
# Out:
# [5713.31222269 5713.84827524 5713.84827524 ... 5696.22962532 5691.98050989
#  5689.85918111]
#
#
# Coefficients:[0.000 1.989 -0.000 0.000 -0.000] - b:-27.30
#
#
# The model coefficients are: for degree 4 - x^0, x^1, x^2, x^3, X^4
# [ 0.00000000e+00  1.98930377e+00 -3.45908682e-04  2.71156462e-08
#  -6.67021993e-13]
# The model intercepts are  -27.304419043461166
#
#
# Coefficients using statsmodel
# Intercept      -2.642120e-11
# Pressure        1.000000e+00
# Pressure ^ 2   -3.302913e-13
# Pressure ^ 3   -1.822431e-13
# Pressure ^ 4   -6.238803e-14
# dtype: float64
#
#
# Coefficients using SK-Learn Polynomial Regression Model
# The model coefficients are: for degree 4 - x^0, x^1, x^2, x^3, X^4
# [ 0.00000000e+00  1.98930377e+00 -3.45908682e-04  2.71156462e-08
#  -6.67021993e-13]
# The model intercepts are  -27.304419043461166
# Compare the results of statsmodel and sk-learn for polynomial regression model
#
#
# Mean Absolute Error, MAE is  125.98204528409207
# Mean Squared Error, MSE is  205535.85142597576
# Root Mean Square Error is  453.3606196241307
#
#
# Coefficient of determination or R squared value is
# 0.8134012042693171

# %% [markdown]
# Machine Learning: Predicting temperature by using temperature value as a predictor.

# %% [markdown]
# Regression

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
data.columns
# Out:
# Index(['Time', 'Temperature', 'RH', 'Pressure', 'Wind Speed', 'Wind Direction',
#        'Rainfall'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43822 entries, 0 to 43821
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Time            43822 non-null  object
#  1   Temperature     43822 non-null  int64
#  2   RH              43822 non-null  int64
#  3   Pressure        43822 non-null  int64
#  4   Wind Speed      43822 non-null  int64
#  5   Wind Direction  43822 non-null  int64
#  6   Rainfall        43822 non-null  int64
# dtypes: int64(6), object(1)
# memory usage: 2.3+ MB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43822 entries, 0 to 43821
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Time            43822 non-null  object
#  1   Temperature     43822 non-null  int64
#  2   RH              43822 non-null  int64
#  3   Pressure        43822 non-null  int64
#  4   Wind Speed      43822 non-null  int64
#  5   Wind Direction  43822 non-null  int64
#  6   Rainfall        43822 non-null  int64
# dtypes: int64(6), object(1)
# memory usage: 2.3+ MB

# %%
data['Temperature'].value_counts()
# Out:
# 30     842
# 35     748
# 45     732
# 43     610
# 31     606
#       ...
# 171      3
# 227      3
# 234      2
# 229      1
# 173      1
# Name: Temperature, Length: 322, dtype: int64

# %%
data['RH'].value_counts()
# Out:
# 96     1552
# 97     1417
# 98     1354
# 63     1345
# 65     1271
#        ...
# 194       4
# 142       2
# 148       1
# 146       1
# 144       1
# Name: RH, Length: 100, dtype: int64

# %%
round(100*(data.isnull().sum()/len(data.index)),2) #Checking the number of null in percentage
# Out:
# Time              0.0
# Temperature       0.0
# RH                0.0
# Pressure          0.0
# Wind Speed        0.0
# Wind Direction    0.0
# Rainfall          0.0
# dtype: float64

# %%
import numpy as np

# %%
smart_new = data[list(data.dtypes[data.dtypes!= 'object'].index)]

# %%
weather_y =smart_new.pop('Temperature')
weather_x = smart_new

# %% [markdown]
# Splitting Data for training and Testing purpose

# %%
train_x,test_x,train_y,test_y = train_test_split(weather_x ,weather_y,test_size=0.2 ,random_state = 4)

# %%
train_x.head()
# Out:
#         RH  Pressure  Wind Speed  Wind Direction  Rainfall
# 11398   46      9894          12             225      5647
# 7089    51      9894           6             292      5647
# 4660    91      9870          13             292      5646
# 30592   95     10079           8             225      5808
# 37790  186     19608          26             584     11914

# %% [markdown]
# Building the model

# %% [markdown]
# Linear Regression

# %%
model = LinearRegression()
model.fit(train_x,train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
prediction = model.predict(test_x)

# %%
# calculating the error and any thing above 1 degree celcius is actually not a good model
np.mean((prediction-test_y)**2)
# Out:
# 2365.4585126318448

# %%
 pd.DataFrame({'actual': test_y,
             'prediction': prediction,
             'diff':(test_y-prediction)})
# Out:
#        actual  prediction        diff
# 17606      68   66.795118    1.204882
# 31737      32   61.913941  -29.913941
# 14452      78   53.757548   24.242452
# 1704      178   70.392162  107.607838
# 43022     -42   44.158740  -86.158740
# ...       ...         ...         ...
# 7875       99   60.738546   38.261454
# 28195      40   52.312833  -12.312833
# 14475      78   52.148021   25.851979
# 29411      37   54.256209  -17.256209
# 7687      100   55.598280   44.401720
#
# [8765 rows x 3 columns]

# %% [markdown]
# Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree = 4)
poly_x = poly.fit_transform(train_x)

poly.fit(poly_x,train_y)
lin2 = LinearRegression()
lin2.fit(poly_x,train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
prediction2 =lin2.predict(poly.fit_transform(test_x))
#calculating the error
np.mean((prediction2-test_y)**2)
# Out:
# 107.37173926248923

# %%
pd.DataFrame({'actual': test_y,
             'prediction': prediction2,
             'Diff':(test_y-prediction2)
})
# Out:
#        actual  prediction       Diff
# 17606      68   71.404186  -3.404186
# 31737      32   30.888257   1.111743
# 14452      78   86.632072  -8.632072
# 1704      178  188.029705 -10.029705
# 43022     -42   -8.154549 -33.845451
# ...       ...         ...        ...
# 7875       99   96.405495   2.594505
# 28195      40   41.795331  -1.795331
# 14475      78   86.850306  -8.850306
# 29411      37   37.432950  -0.432950
# 7687      100   90.654213   9.345787
#
# [8765 rows x 3 columns]

# %% [markdown]
# CART(Decission Tree regressor)

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(train_x,train_y)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=0, splitter='best')

# %%
prediction3 = regressor.predict(test_x)
np.mean((prediction-test_y)**2)
# Out:
# 2365.4585126318448

# %%
pd.DataFrame({'actual': test_y,
             'prediction': prediction3,
             'Diff':(test_y-prediction3)
  }  )
# Out:
#        actual  prediction  Diff
# 17606      68        68.0   0.0
# 31737      32        32.0   0.0
# 14452      78        78.0   0.0
# 1704      178       178.0   0.0
# 43022     -42       -42.0   0.0
# ...       ...         ...   ...
# 7875       99        99.0   0.0
# 28195      40        40.0   0.0
# 14475      78        78.0   0.0
# 29411      37        37.0   0.0
# 7687      100       100.0   0.0
#
# [8765 rows x 3 columns]

# %% [markdown]
# Random Forest

# %%
# Random Forest max depth 10
from sklearn.ensemble import RandomForestRegressor
regr = RandomForestRegressor(max_depth=10,random_state=0,n_estimators=100)
regr.fit(train_x,train_y)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=10, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
prediction4 = regr.predict(test_x)
np.mean((prediction-test_y)**2)
# Out:
# 2365.4585126318448

# %%
pd.DataFrame({'actual': test_y,
             'prediction': prediction4,
             'Diff':(test_y-prediction4)
})
# Out:
#        actual  prediction      Diff
# 17606      68   68.001011 -0.001011
# 31737      32   31.998273  0.001727
# 14452      78   77.919421  0.080579
# 1704      178  178.806477 -0.806477
# 43022     -42  -40.341559 -1.658441
# ...       ...         ...       ...
# 7875       99   94.483487  4.516513
# 28195      40   39.960798  0.039202
# 14475      78   77.211629  0.788371
# 29411      37   37.000000  0.000000
# 7687      100   99.754437  0.245563
#
# [8765 rows x 3 columns]

# %%
# Random Forest max depth 50
from sklearn.ensemble import RandomForestRegressor
regre = RandomForestRegressor(max_depth=50,random_state=0,n_estimators=100)
regre.fit(train_x,train_y)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=50, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
prediction5 = regre.predict(test_x)
np.mean((prediction-test_y)**2)
# Out:
# 2365.4585126318448

# %%
pd.DataFrame({'actual': test_y,
             'prediction': prediction5,
             'Diff':(test_y-prediction5)
 } )
# Out:
#        actual  prediction  Diff
# 17606      68       68.00  0.00
# 31737      32       32.00  0.00
# 14452      78       78.00  0.00
# 1704      178      178.90 -0.90
# 43022     -42      -41.86 -0.14
# ...       ...         ...   ...
# 7875       99       98.57  0.43
# 28195      40       40.00  0.00
# 14475      78       77.98  0.02
# 29411      37       37.00  0.00
# 7687      100      100.00  0.00
#
# [8765 rows x 3 columns]

# %%
#Multiple Linear Regression Plot, prediction model, and the visual plot
import seaborn as sns
import pandas as pd
 
sns.set_style()
# Load the dataset


print(dataset.head())
 
# Plot Temperature and Y by RH
g = sns.lmplot(data=dataset,
    x="RH", y="Temperature", hue="RH", height=5
)
 
# Use more informative axis labels than are provided by default
g.set_axis_labels("Temperature", "RH")
 
#Pairwise plot by RH
g = sns.PairGrid(dataset, hue = "RH")
g.map(sns.scatterplot)
 
 
#Pairwise plot
g = sns.PairGrid(dataset)
g.map(sns.scatterplot)
# Out:
#                       Time  Temperature  ...  Wind Direction  Rainfall
# 0  2017-10-21T09:22:54.000          262  ...             292      5367
# 1  2017-10-21T09:23:55.000          262  ...             315      5367
# 2  2017-10-21T09:24:56.000          262  ...             270      5367
# 3  2017-10-21T09:25:59.000          262  ...             315      5367
# 4  2017-10-21T09:27:02.000          261  ...             292      5367
#
# [5 rows x 7 columns]

# %%
#Example  Multiple Linear Regression Plot and the prediction model
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
 
dataset= pd.read_excel("final.xlsx") 

print(dataset.head())
print("\n")
 
#Use only 1 feature - AGE to predict the target Y
sensor_x = dataset[['Temperature', 'RH' , 'Pressure', 'Wind Speed', 'Wind Direction']]
sensor_y = dataset[['Rainfall']]
 
#Split the dataset into training and testing sets (80%:20%)
x_train,x_test,y_train,y_test=train_test_split(sensor_x, sensor_y,test_size=0.2)
print(x_train)
print("\n")
print(y_train)
print("\n")
print(x_test)
 
#Create linear regression object
regr = LinearRegression()
 
# Train the model using the training sets 
regr.fit(x_train, y_train)
 
# Make predictions using the testing set
y_pred = regr.predict(x_test)
 
#Make prediction for the following:
pTemp =251
pRH = 57
pP = 9985
pWS = 13
pWD = 247


print("\n")
print ('Predicted Y value: ', regr.predict([[pTemp, pRH, pP, pWS, pWD]]))
print("\n")
 
# The coefficients
print('Coefficients: \n', regr.coef_)
print("\n")
 
# The mean squared error
print('Mean squared error: ', mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: ', r2_score(y_test, y_pred))
 
 
#Use statsmodel for model summary
sensor_x = sm.add_constant(sensor_x)
model = sm.OLS(sensor_y, sensor_x).fit()
predictions = model.predict(sensor_x)
print_model = model.summary()
print(print_model)
# Out:
#                       Time  Temperature  ...  Wind Direction  Rainfall
# 0  2017-10-21T09:22:54.000          262  ...             292      5367
# 1  2017-10-21T09:23:55.000          262  ...             315      5367
# 2  2017-10-21T09:24:56.000          262  ...             270      5367
# 3  2017-10-21T09:25:59.000          262  ...             315      5367
# 4  2017-10-21T09:27:02.000          261  ...             292      5367
#
# [5 rows x 7 columns]
#
#
#        Temperature   RH  Pressure  Wind Speed  Wind Direction
# 29730           36   81     10045           0             270
# 38224           13   70      9892          13             225
# 20694           61  100      9882           6              67
# 15858           74   94      9901           0             315
# 7447           101   57      9848           0              45
# ...            ...  ...       ...         ...             ...
# 33507           29   65      9971          20             292
# 5404           111   79      9875          10             270
# 27651           42   77     10128           0             247
# 37152           18   95      9839          12             315
# 10103           90   63      9918          13             225
#
# [35057 rows x 5 columns]
#
#
#        Rainfall
# 29730      5787
# 38224      5957
# 20694      5776
# 15858      5686
# 7447       5647
# ...         ...
# 33507      5808
# 5404       5647
# 27651      5778
# 37152      5866
# 10103      5647
#
# [35057 rows x 1 columns]
#
#
#        Temperature  RH  Pressure  Wind Speed  Wind Direction
# 35185           25  75      9978           9             247
# 25680           45  63      9979           5             270
# 9155            93  69      9890           6             247
# 23827           50  77     10066           0             315
# 32624           30  93     10060           0             315
# ...            ...  ..       ...         ...             ...
# 12538           83  64      9849          15             270
# 23929           50  75     10066           0             247
# 28239           40  66     10096           0              22
# 38331           13  70      9895           0             270
# 16402           72  98      9911           0             270
#
# [8765 rows x 5 columns]
#
#
# Predicted Y value:  [[5379.16788286]]
#
#
# Coefficients:
#  [[-1.69038002  2.30605544  0.56510413  3.9117977   0.90487777]]
#
#
# Mean squared error:  148829.27700673326
# Coefficient of determination:  0.8599718154812495
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Rainfall   R-squared:                       0.824
# Model:                            OLS   Adj. R-squared:                  0.824
# Method:                 Least Squares   F-statistic:                 4.104e+04
# Date:                Thu, 27 May 2021   Prob (F-statistic):               0.00
# Time:                        00:07:54   Log-Likelihood:            -3.2894e+05
# No. Observations:               43822   AIC:                         6.579e+05
# Df Residuals:                   43816   BIC:                         6.579e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           -243.6829     14.392    -16.932      0.000    -271.891    -215.475
# Temperature       -1.7184      0.042    -40.765      0.000      -1.801      -1.636
# RH                 2.2353      0.128     17.420      0.000       1.984       2.487
# Pressure           0.5669      0.002    299.373      0.000       0.563       0.571
# Wind Speed         3.7158      0.213     17.452      0.000       3.299       4.133
# Wind Direction     0.8715      0.024     35.884      0.000       0.824       0.919
# ==============================================================================
# Omnibus:                    73913.915   Durbin-Watson:                   0.321
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         41699010.233
# Skew:                         -11.918   Prob(JB):                         0.00
# Kurtosis:                     152.229   Cond. No.                     6.98e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.98e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
